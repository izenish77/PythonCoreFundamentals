# %%
import csv

# %%
with open('sample2.csv') as csv_file:
    csv_reader=csv.reader(csv_file,delimiter=',')
    line_count=0
    for row in csv_reader:
        print(f'Column names are {",".join(row)}')
# Out:
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Adam Donachie, "BAL", "Catcher", 74, 180, 22.99
# Column names are Paul Bako, "BAL", "Catcher", 74, 215, 34.69
# Column names are Ramon Hernandez, "BAL", "Catcher", 72, 210, 30.78
# Column names are Kevin Millar, "BAL", "First Baseman", 72, 210, 35.43
# Column names are Chris Gomez, "BAL", "First Baseman", 73, 188, 35.71
# Column names are Brian Roberts, "BAL", "Second Baseman", 69, 176, 29.39
# Column names are Miguel Tejada, "BAL", "Shortstop", 69, 209, 30.77
# Column names are Melvin Mora, "BAL", "Third Baseman", 71, 200, 35.07
# Column names are Aubrey Huff, "BAL", "Third Baseman", 76, 231, 30.19
# Column names are Adam Stern, "BAL", "Outfielder", 71, 180, 27.05
# Column names are Jeff Fiorentino, "BAL", "Outfielder", 73, 188, 23.88
# Column names are Freddie Bynum, "BAL", "Outfielder", 73, 180, 26.96
# Column names are Nick Markakis, "BAL", "Outfielder", 74, 185, 23.29
# Column names are Brandon Fahey, "BAL", "Outfielder", 74, 160, 26.11
# Column names are Corey Patterson, "BAL", "Outfielder", 69, 180, 27.55
# Column names are Jay Payton, "BAL", "Outfielder", 70, 185, 34.27
# Column names are Jay Gibbons, "BAL", "Designated Hitter", 72, 197, 30
# Column names are Erik Bedard, "BAL", "Starting Pitcher", 73, 189, 27.99
# Column names are Hayden Penn, "BAL", "Starting Pitcher", 75, 185, 22.38
# Column names are Adam Loewen, "BAL", "Starting Pitcher", 78, 219, 22.89
# Column names are Daniel Cabrera, "BAL", "Starting Pitcher", 79, 230, 25.76
# Column names are Steve Trachsel, "BAL", "Starting Pitcher", 76, 205, 36.33
# Column names are Jaret Wright, "BAL", "Starting Pitcher", 74, 230, 31.17
# Column names are Kris Benson, "BAL", "Starting Pitcher", 76, 195, 32.31
# Column names are Scott Williamson, "BAL", "Relief Pitcher", 72, 180, 31.03
# Column names are John Parrish, "BAL", "Relief Pitcher", 71, 192, 29.26
# Column names are Danys Baez, "BAL", "Relief Pitcher", 75, 225, 29.47
# Column names are Chad Bradford, "BAL", "Relief Pitcher", 77, 203, 32.46
# Column names are Jamie Walker, "BAL", "Relief Pitcher", 74, 195, 35.67
# Column names are Brian Burres, "BAL", "Relief Pitcher", 73, 182, 25.89
# Column names are Kurt Birkins, "BAL", "Relief Pitcher", 74, 188, 26.55
# Column names are James Hoey, "BAL", "Relief Pitcher", 78, 200, 24.17
# Column names are Sendy Rleal, "BAL", "Relief Pitcher", 73, 180, 26.69
# Column names are Chris Ray, "BAL", "Relief Pitcher", 75, 200, 25.13
# Column names are Jeremy Guthrie, "BAL", "Relief Pitcher", 73, 200, 27.9
# Column names are A.J. Pierzynski, "CWS", "Catcher", 75, 245, 30.17
# Column names are Toby Hall, "CWS", "Catcher", 75, 240, 31.36
# Column names are Paul Konerko, "CWS", "First Baseman", 74, 215, 30.99
# Column names are Tadahito Iguchi, "CWS", "Second Baseman", 69, 185, 32.24
# Column names are Juan Uribe, "CWS", "Shortstop", 71, 175, 27.61
# Column names are Alex Cintron, "CWS", "Shortstop", 74, 199, 28.2
# Column names are Joe Crede, "CWS", "Third Baseman", 73, 200, 28.85
# Column names are Josh Fields, "CWS", "Third Baseman", 73, 215, 24.21
# Column names are Ryan Sweeney, "CWS", "Outfielder", 76, 200, 22.02
# Column names are Brian N. Anderson, "CWS", "Outfielder", 74, 205, 24.97
# Column names are Luis Terrero, "CWS", "Outfielder", 74, 206, 26.78
# Column names are Pablo Ozuna, "CWS", "Outfielder", 70, 186, 32.51
# Column names are Scott Podsednik, "CWS", "Outfielder", 72, 188, 30.95
# Column names are Jermaine Dye, "CWS", "Outfielder", 77, 220, 33.09
# Column names are Darin Erstad, "CWS", "Outfielder", 74, 210, 32.74
# Column names are Rob Mackowiak, "CWS", "Outfielder", 70, 195, 30.69
# Column names are Jim Thome, "CWS", "Designated Hitter", 76, 244, 36.51
# Column names are Jerry Owens, "CWS", "Designated Hitter", 75, 195, 26.03
# Column names are Charlie Haeger, "CWS", "Starting Pitcher", 73, 200, 23.45
# Column names are Heath Phillips, "CWS", "Starting Pitcher", 75, 200, 24.94
# Column names are Gavin Floyd, "CWS", "Starting Pitcher", 76, 212, 24.09
# Column names are Jose Contreras, "CWS", "Starting Pitcher", 76, 224, 35.23
# Column names are Jon Garland, "CWS", "Starting Pitcher", 78, 210, 27.43
# Column names are Javier Vazquez, "CWS", "Starting Pitcher", 74, 205, 30.6
# Column names are Mark Buehrle, "CWS", "Starting Pitcher", 74, 220, 27.94
# Column names are Mike MacDougal, "CWS", "Relief Pitcher", 76, 195, 29.99
# Column names are David Aardsma, "CWS", "Relief Pitcher", 77, 200, 25.17
# Column names are Andrew Sisco, "CWS", "Relief Pitcher", 81, 260, 24.13
# Column names are Matt Thornton, "CWS", "Relief Pitcher", 78, 228, 30.46
# Column names are Bobby Jenks, "CWS", "Relief Pitcher", 75, 270, 25.96
# Column names are Boone Logan, "CWS", "Relief Pitcher", 77, 200, 22.55
# Column names are Sean Tracey, "CWS", "Relief Pitcher", 75, 210, 26.29
# Column names are Nick Masset, "CWS", "Relief Pitcher", 76, 190, 24.79
# Column names are Jose Molina, "ANA", "Catcher", 74, 220, 31.74
# Column names are Jeff Mathis, "ANA", "Catcher", 72, 180, 23.92
# Column names are Mike Napoli, "ANA", "Catcher", 72, 205, 25.33
# Column names are Casey Kotchman, "ANA", "First Baseman", 75, 210, 24.02
# Column names are Kendry Morales, "ANA", "First Baseman", 73, 220, 23.7
# Column names are Shea Hillenbrand, "ANA", "First Baseman", 73, 211, 31.59
# Column names are Robb Quinlan, "ANA", "First Baseman", 73, 200, 29.95
# Column names are Howie Kendrick, "ANA", "First Baseman", 70, 180, 23.64
# Column names are Orlando Cabrera, "ANA", "Shortstop", 70, 190, 32.33
# Column names are Erick Aybar, "ANA", "Shortstop", 70, 170, 23.13
# Column names are Dallas McPherson, "ANA", "Third Baseman", 76, 230, 26.6
# Column names are Maicer Izturis, "ANA", "Third Baseman", 68, 155, 26.46
# Column names are Reggie Willits, "ANA", "Outfielder", 71, 185, 25.75
# Column names are Tommy Murphy, "ANA", "Outfielder", 72, 185, 27.51
# Column names are Terry Evans, "ANA", "Outfielder", 75, 200, 25.11
# Column names are Gary Matthews Jr., "ANA", "Outfielder", 75, 225, 32.51
# Column names are Garret Anderson, "ANA", "Outfielder", 75, 225, 34.67
# Column names are Vladimir Guerrero, "ANA", "Outfielder", 75, 220, 31.06
# Column names are Chone Figgins, "ANA", "Outfielder", 68, 160, 29.1
# Column names are Juan Rivera, "ANA", "Outfielder", 74, 205, 28.66
# Column names are John Lackey, "ANA", "Starting Pitcher", 78, 235, 28.35
# Column names are Bartolo Colon, "ANA", "Starting Pitcher", 71, 250, 33.77
# Column names are Kelvim Escobar, "ANA", "Starting Pitcher", 73, 210, 30.89
# Column names are Dustin Moseley, "ANA", "Starting Pitcher", 76, 190, 37.74
# Column names are Ervin Santana, "ANA", "Starting Pitcher", 74, 160, 24.14
# Column names are Joe Saunders, "ANA", "Starting Pitcher", 74, 200, 25.71
# Column names are Jered Weaver, "ANA", "Starting Pitcher", 79, 205, 24.41
# Column names are Chris Resop, "ANA", "Relief Pitcher", 75, 222, 24.32
# Column names are Phil Seibel, "ANA", "Relief Pitcher", 73, 195, 28.09
# Column names are Justin Speier, "ANA", "Relief Pitcher", 76, 205, 33.31
# Column names are Darren Oliver, "ANA", "Relief Pitcher", 74, 220, 36.4
# Column names are Hector Carrasco, "ANA", "Relief Pitcher", 74, 220, 37.36
# Column names are Scot Shields, "ANA", "Relief Pitcher", 73, 170, 31.61
# Column names are Francisco Rodriguez, "ANA", "Relief Pitcher", 72, 185, 25.14
# Column names are Greg Jones, "ANA", "Relief Pitcher", 74, 195, 30.29
# Column names are Doug Mirabelli, "BOS", "Catcher", 73, 220, 36.37
# Column names are Jason Varitek, "BOS", "Catcher", 74, 230, 34.89
# Column names are George Kottaras, "BOS", "Catcher", 72, 180, 23.79
# Column names are Kevin Youkilis, "BOS", "First Baseman", 73, 220, 27.96
# Column names are Dustin Pedroia, "BOS", "Second Baseman", 69, 180, 23.54
# Column names are Alex Cora, "BOS", "Shortstop", 72, 180, 31.37
# Column names are Julio Lugo, "BOS", "Shortstop", 73, 170, 31.29
# Column names are Mike Lowell, "BOS", "Third Baseman", 75, 210, 33.01
# Column names are Wily Mo Pe?a, "BOS", "Outfielder", 75, 215, 25.1
# Column names are J.D. Drew, "BOS", "Outfielder", 73, 200, 31.28
# Column names are Manny Ramirez, "BOS", "Outfielder", 72, 213, 34.75
# Column names are Brandon Moss, "BOS", "Outfielder", 72, 180, 23.46
# Column names are David Murphy, "BOS", "Outfielder", 76, 192, 25.37
# Column names are Eric Hinske, "BOS", "Outfielder", 74, 235, 29.57
# Column names are Coco Crisp, "BOS", "Outfielder", 72, 185, 27.33
# Column names are David Ortiz, "BOS", "Designated Hitter", 76, 230, 31.28
# Column names are Curt Schilling, "BOS", "Starting Pitcher", 77, 235, 40.29
# Column names are Tim Wakefield, "BOS", "Starting Pitcher", 74, 210, 40.58
# Column names are Josh Beckett, "BOS", "Starting Pitcher", 77, 222, 26.79
# Column names are Matt Clement, "BOS", "Starting Pitcher", 75, 210, 32.55
# Column names are Jonathan Papelbon, "BOS", "Starting Pitcher", 76, 230, 26.27
# Column names are Kyle Snyder, "BOS", "Starting Pitcher", 80, 220, 29.47
# Column names are Devern Hansack, "BOS", "Starting Pitcher", 74, 180, 29.07
# Column names are Jon Lester, "BOS", "Starting Pitcher", 74, 190, 23.15
# Column names are Kason Gabbard, "BOS", "Starting Pitcher", 75, 200, 24.9
# Column names are Craig Hansen, "BOS", "Relief Pitcher", 78, 210, 23.29
# Column names are Hideki Okajima, "BOS", "Relief Pitcher", 73, 194, 31.18
# Column names are Craig Breslow, "BOS", "Relief Pitcher", 73, 180, 26.56
# Column names are Manny Delcarmen, "BOS", "Relief Pitcher", 74, 190, 25.03
# Column names are Brendan Donnelly, "BOS", "Relief Pitcher", 75, 240, 35.66
# Column names are Javier Lopez, "BOS", "Relief Pitcher", 76, 200, 29.64
# Column names are J.C. Romero, "BOS", "Relief Pitcher", 71, 198, 30.74
# Column names are Joel Pineiro, "BOS", "Relief Pitcher", 73, 200, 28.43
# Column names are Julian Tavarez, "BOS", "Relief Pitcher", 74, 195, 33.77
# Column names are Mike Timlin, "BOS", "Relief Pitcher", 76, 210, 40.97
# Column names are Nick DeBarr, "BOS", "Relief Pitcher", 76, 220, 23.52
# Column names are Victor Martinez, "CLE", "Catcher", 74, 190, 28.19
# Column names are Kelly Shoppach, "CLE", "Catcher", 73, 210, 26.84
# Column names are Ryan Garko, "CLE", "First Baseman", 74, 225, 26.16
# Column names are Joe Inglett, "CLE", "Second Baseman", 70, 180, 28.67
# Column names are Josh Barfield, "CLE", "Second Baseman", 72, 185, 24.2
# Column names are Hector Luna, "CLE", "Second Baseman", 73, 170, 27.08
# Column names are Jhonny Peralta, "CLE", "Shortstop", 73, 185, 24.76
# Column names are Andy Marte, "CLE", "Third Baseman", 73, 185, 23.36
# Column names are Ben Francisco, "CLE", "Outfielder", 73, 180, 25.35
# Column names are Shin-Soo Choo, "CLE", "Outfielder", 71, 178, 24.63
# Column names are Franklin Gutierrez, "CLE", "Outfielder", 74, 175, 24.02
# Column names are Grady Sizemore, "CLE", "Outfielder", 74, 200, 24.58
# Column names are Jason Michaels, "CLE", "Outfielder", 72, 204, 30.82
# Column names are Trot Nixon, "CLE", "Outfielder", 74, 211, 32.89
# Column names are David Dellucci, "CLE", "Outfielder", 71, 190, 33.33
# Column names are Casey Blake, "CLE", "Outfielder", 74, 210, 33.52
# Column names are Travis Hafner, "CLE", "Designated Hitter", 75, 240, 29.74
# Column names are Paul Byrd, "CLE", "Starting Pitcher", 73, 190, 36.24
# Column names are Cliff Lee, "CLE", "Starting Pitcher", 75, 190, 28.5
# Column names are Jake Westbrook, "CLE", "Starting Pitcher", 75, 185, 29.42
# Column names are C.C. Sabathia, "CLE", "Starting Pitcher", 79, 290, 26.61
# Column names are Jeremy Sowers, "CLE", "Starting Pitcher", 73, 175, 23.79
# Column names are Rafael Perez, "CLE", "Relief Pitcher", 75, 185, 24.96
# Column names are Brian Slocum, "CLE", "Relief Pitcher", 76, 200, 25.93
# Column names are Edward Mujica, "CLE", "Relief Pitcher", 74, 220, 22.81
# Column names are Fernando Cabrera, "CLE", "Relief Pitcher", 76, 170, 25.29
# Column names are Tom Mastny, "CLE", "Relief Pitcher", 78, 220, 26.07
# Column names are Juan Lara, "CLE", "Relief Pitcher", 74, 190, 26.09
# Column names are Fausto Carmona, "CLE", "Relief Pitcher", 76, 220, 23.23
# Column names are Aaron Fultz, "CLE", "Relief Pitcher", 72, 205, 33.49
# Column names are Rafael Betancourt, "CLE", "Relief Pitcher", 74, 200, 31.84
# Column names are Roberto Hernandez, "CLE", "Relief Pitcher", 76, 250, 42.3
# Column names are Joe Borowski, "CLE", "Relief Pitcher", 74, 225, 35.82
# Column names are Matt Miller, "CLE", "Relief Pitcher", 75, 215, 35.27
# Column names are Jason Davis, "CLE", "Relief Pitcher", 78, 210, 26.81
# Column names are Mike Piazza, "OAK", "Catcher", 75, 215, 38.49
# Column names are Jason Kendall, "OAK", "Catcher", 72, 195, 32.68
# Column names are Adam Melhuse, "OAK", "Catcher", 74, 200, 34.93
# Column names are Nick Swisher, "OAK", "First Baseman", 72, 194, 26.26
# Column names are Dan Johnson, "OAK", "First Baseman", 74, 220, 27.56
# Column names are Donald Murphy, "OAK", "Second Baseman", 70, 180, 23.98
# Column names are Mark Ellis, "OAK", "Second Baseman", 71, 180, 29.73
# Column names are Marco Scutaro, "OAK", "Shortstop", 70, 170, 31.33
# Column names are Bobby Crosby, "OAK", "Shortstop", 75, 195, 27.13
# Column names are Mark Kiger, "OAK", "Shortstop", 71, 180, 26.75
# Column names are Antonio Perez, "OAK", "Third Baseman", 71, 170, 27.09
# Column names are Eric Chavez, "OAK", "Third Baseman", 73, 206, 29.23
# Column names are Milton Bradley, "OAK", "Outfielder", 72, 205, 28.88
# Column names are Shannon Stewart, "OAK", "Outfielder", 71, 200, 33.01
# Column names are Bobby Kielty, "OAK", "Outfielder", 73, 225, 30.57
# Column names are Mark Kotsay, "OAK", "Outfielder", 72, 201, 31.24
# Column names are Ryan Goleski, "OAK", "Outfielder", 75, 225, 24.95
# Column names are Jeremy Brown, "OAK", "Designated Hitter", 70, 226, 27.35
# Column names are Jason Windsor, "OAK", "Starting Pitcher", 74, 233, 24.62
# Column names are David Shafer, "OAK", "Starting Pitcher", 74, 180, 24.98
# Column names are Joe Blanton, "OAK", "Starting Pitcher", 75, 225, 26.22
# Column names are Brad Halsey, "OAK", "Starting Pitcher", 73, 180, 26.04
# Column names are Dan Haren, "OAK", "Starting Pitcher", 77, 220, 26.45
# Column names are Rich Harden, "OAK", "Starting Pitcher", 73, 180, 25.25
# Column names are Joe Kennedy, "OAK", "Starting Pitcher", 76, 237, 27.77
# Column names are Esteban Loaiza, "OAK", "Starting Pitcher", 75, 215, 35.16
# Column names are Alan Embree, "OAK", "Relief Pitcher", 74, 190, 37.1
# Column names are Jay Witasick, "OAK", "Relief Pitcher", 76, 235, 34.51
# Column names are Justin Duchscherer, "OAK", "Relief Pitcher", 75, 190, 29.28
# Column names are Kiko Calero, "OAK", "Relief Pitcher", 73, 180, 32.14
# Column names are Chad Gaudin, "OAK", "Relief Pitcher", 71, 165, 23.94
# Column names are Lenny DiNardo, "OAK", "Relief Pitcher", 76, 195, 27.45
# Column names are Scott Dunn, "OAK", "Relief Pitcher", 75, 200, 28.77
# Column names are Huston Street, "OAK", "Relief Pitcher", 72, 190, 23.58
# Column names are Ron Flores, "OAK", "Relief Pitcher", 71, 190, 27.56
# Column names are Jay Marshall, "OAK", "Relief Pitcher", 77, 185, 24.01
# Column names are Marcus McBeth, "OAK", "Relief Pitcher", 73, 185, 26.52
# Column names are Jorge Posada, "NYY", "Catcher", 74, 205, 35.54
# Column names are Wil Nieves, "NYY", "Catcher", 71, 190, 29.43
# Column names are Andy Phillips, "NYY", "First Baseman", 72, 205, 29.9
# Column names are Doug Mientkiewicz, "NYY", "First Baseman", 74, 206, 32.7
# Column names are Josh Phelps, "NYY", "First Baseman", 75, 220, 28.8
# Column names are Miguel Cairo, "NYY", "Second Baseman", 73, 208, 32.82
# Column names are Robinson Cano, "NYY", "Second Baseman", 72, 170, 24.36
# Column names are Derek Jeter, "NYY", "Shortstop", 75, 195, 32.68
# Column names are Alex Rodriguez, "NYY", "Third Baseman", 75, 210, 31.59
# Column names are Johnny Damon, "NYY", "Outfielder", 74, 190, 33.32
# Column names are Bobby Abreu, "NYY", "Outfielder", 72, 211, 32.97
# Column names are Hideki Matsui, "NYY", "Outfielder", 74, 230, 32.72
# Column names are Melky Cabrera, "NYY", "Outfielder", 71, 170, 22.55
# Column names are Kevin Thompson, "NYY", "Outfielder", 70, 185, 27.45
# Column names are Jason Giambi, "NYY", "Designated Hitter", 75, 230, 36.14
# Column names are Mike Mussina, "NYY", "Starting Pitcher", 74, 185, 38.23
# Column names are Carl Pavano, "NYY", "Starting Pitcher", 77, 241, 31.14
# Column names are Andy Pettitte, "NYY", "Starting Pitcher", 77, 225, 34.71
# Column names are Darrell Rasner, "NYY", "Starting Pitcher", 75, 210, 26.13
# Column names are Jeff Karstens, "NYY", "Starting Pitcher", 75, 175, 24.43
# Column names are Humberto Sanchez, "NYY", "Starting Pitcher", 78, 230, 23.76
# Column names are Chien-Ming Wang, "NYY", "Starting Pitcher", 75, 200, 26.92
# Column names are Sean Henn, "NYY", "Relief Pitcher", 76, 215, 25.85
# Column names are Scott Proctor, "NYY", "Relief Pitcher", 73, 198, 30.16
# Column names are Brian Bruney, "NYY", "Relief Pitcher", 75, 226, 25.03
# Column names are Chris Britton, "NYY", "Relief Pitcher", 75, 278, 24.21
# Column names are T.J. Beam, "NYY", "Relief Pitcher", 79, 215, 26.51
# Column names are Jose Veras, "NYY", "Relief Pitcher", 77, 230, 26.36
# Column names are Kyle Farnsworth, "NYY", "Relief Pitcher", 76, 240, 30.88
# Column names are Luis Vizcaino, "NYY", "Relief Pitcher", 71, 184, 32.57
# Column names are Mike Myers, "NYY", "Relief Pitcher", 75, 219, 37.68
# Column names are Mariano Rivera, "NYY", "Relief Pitcher", 74, 170, 37.25
# Column names are Ivan Rodriguez, "DET", "Catcher", 69, 218, 35.25
# Column names are Vance Wilson, "DET", "Catcher", 71, 190, 33.95
# Column names are Sean Casey, "DET", "First Baseman", 76, 225, 32.66
# Column names are Chris Shelton, "DET", "First Baseman", 72, 220, 26.68
# Column names are Omar Infante, "DET", "Second Baseman", 72, 176, 25.18
# Column names are Placido Polanco, "DET", "Second Baseman", 70, 190, 31.39
# Column names are Neifi Perez, "DET", "Second Baseman", 72, 197, 33.74
# Column names are Carlos Guillen, "DET", "Shortstop", 73, 204, 31.42
# Column names are Ramon Santiago, "DET", "Shortstop", 71, 167, 27.5
# Column names are Tony Giarratano, "DET", "Shortstop", 72, 180, 24.25
# Column names are Brandon Inge, "DET", "Third Baseman", 71, 195, 29.78
# Column names are Craig Monroe, "DET", "Outfielder", 73, 220, 30
# Column names are Magglio Ordo?ez, "DET", "Outfielder", 72, 215, 33.09
# Column names are Curtis Granderson, "DET", "Outfielder", 73, 185, 25.96
# Column names are Brent Clevlen, "DET", "Outfielder", 74, 190, 23.34
# Column names are Marcus Thames, "DET", "Outfielder", 74, 205, 29.98
# Column names are Gary Sheffield, "DET", "Outfielder", 72, 205, 38.28
# Column names are Mike Rabelo, "DET", "Designated Hitter", 73, 200, 27.12
# Column names are Zach Miner, "DET", "Starting Pitcher", 75, 200, 24.97
# Column names are Jeremy Bonderman, "DET", "Starting Pitcher", 74, 210, 24.34
# Column names are Nate Robertson, "DET", "Starting Pitcher", 74, 215, 29.49
# Column names are Justin Verlander, "DET", "Starting Pitcher", 77, 200, 24.02
# Column names are Virgil Vasquez, "DET", "Starting Pitcher", 75, 205, 24.73
# Column names are Kenny Rogers, "DET", "Starting Pitcher", 73, 211, 42.3
# Column names are Mike Maroth, "DET", "Starting Pitcher", 72, 190, 29.54
# Column names are Fernando Rodney, "DET", "Relief Pitcher", 71, 208, 29.95
# Column names are Chad Durbin, "DET", "Relief Pitcher", 74, 200, 29.24
# Column names are Jason Grilli, "DET", "Relief Pitcher", 77, 210, 30.3
# Column names are Jose Mesa, "DET", "Relief Pitcher", 75, 232, 40.77
# Column names are Todd Jones, "DET", "Relief Pitcher", 75, 230, 38.85
# Column names are Joel Zumaya, "DET", "Relief Pitcher", 75, 210, 22.31
# Column names are Jordan Tata, "DET", "Relief Pitcher", 78, 220, 25.44
# Column names are Andrew Miller, "DET", "Relief Pitcher", 78, 210, 21.78
# Column names are Yorman Bazardo, "DET", "Relief Pitcher", 74, 202, 22.64
# Column names are Wilfredo Ledezma, "DET", "Relief Pitcher", 76, 212, 26.11
# Column names are Roman Colon, "DET", "Relief Pitcher", 78, 225, 27.55
# Column names are Edward Campusano, "DET", "Relief Pitcher", 76, 170, 24.63
# Column names are Rene Rivera, "SEA", "Catcher", 70, 190, 23.58
# Column names are Kenji Johjima, "SEA", "Catcher", 72, 200, 30.73
# Column names are Richie Sexson, "SEA", "First Baseman", 80, 237, 32.17
# Column names are Ben Broussard, "SEA", "First Baseman", 74, 220, 30.43
# Column names are Jose Lopez, "SEA", "Second Baseman", 74, 170, 23.27
# Column names are Jose Vidro, "SEA", "Second Baseman", 71, 193, 32.51
# Column names are Yuniesky Betancourt, "SEA", "Shortstop", 70, 190, 25.08
# Column names are Oswaldo Navarro, "SEA", "Shortstop", 72, 150, 22.41
# Column names are Adrian Beltre, "SEA", "Third Baseman", 71, 220, 27.9
# Column names are Raul Ibanez, "SEA", "Outfielder", 74, 200, 34.74
# Column names are Jose Guillen, "SEA", "Outfielder", 71, 190, 30.79
# Column names are Jeremy Reed, "SEA", "Outfielder", 72, 185, 25.71
# Column names are Willie Bloomquist, "SEA", "Outfielder", 71, 185, 29.26
# Column names are Adam Jones, "SEA", "Outfielder", 74, 200, 21.58
# Column names are Ichiro Suzuki, "SEA", "Outfielder", 69, 172, 33.36
# Column names are Mike Morse, "SEA", "Outfielder", 76, 220, 24.94
# Column names are Felix Hernandez, "SEA", "Starting Pitcher", 75, 225, 20.9
# Column names are Ryan Feierabend, "SEA", "Starting Pitcher", 75, 190, 21.52
# Column names are Sean White, "SEA", "Starting Pitcher", 76, 195, 25.85
# Column names are Horacio Ramirez, "SEA", "Starting Pitcher", 73, 219, 27.27
# Column names are Cha Baek, "SEA", "Starting Pitcher", 76, 190, 26.75
# Column names are Miguel Batista, "SEA", "Starting Pitcher", 73, 197, 36.03
# Column names are Jeff Weaver, "SEA", "Starting Pitcher", 77, 200, 30.52
# Column names are Jarrod Washburn, "SEA", "Starting Pitcher", 73, 195, 32.55
# Column names are George Sherrill, "SEA", "Relief Pitcher", 72, 210, 29.86
# Column names are Julio Mateo, "SEA", "Relief Pitcher", 72, 177, 29.58
# Column names are J.J. Putz, "SEA", "Relief Pitcher", 77, 220, 30.02
# Column names are Chris Reitsma, "SEA", "Relief Pitcher", 77, 235, 29.16
# Column names are Cesar Jimenez, "SEA", "Relief Pitcher", 71, 180, 22.3
# Column names are Eric O'Flaherty, "SEA", "Relief Pitcher", 74, 195, 22.06
# Column names are Jon Huber, "SEA", "Relief Pitcher", 74, 195, 25.65
# Column names are Jake Woods, "SEA", "Relief Pitcher", 73, 190, 25.49
# Column names are Sean Green, "SEA", "Relief Pitcher", 78, 230, 27.86
# Column names are Mark Lowe, "SEA", "Relief Pitcher", 75, 190, 23.73
# Column names are Josh Paul, "TB", "Catcher", 73, 200, 31.78
# Column names are Dioner Navarro, "TB", "Catcher", 70, 190, 23.06
# Column names are Shawn Riggans, "TB", "Catcher", 74, 190, 26.6
# Column names are Ty Wigginton, "TB", "First Baseman", 72, 200, 29.39
# Column names are Brendan Harris, "TB", "Second Baseman", 73, 200, 26.51
# Column names are Jorge Cantu, "TB", "Second Baseman", 73, 184, 25.08
# Column names are Ben Zobrist, "TB", "Shortstop", 75, 200, 25.76
# Column names are B.J. Upton, "TB", "Third Baseman", 75, 180, 22.52
# Column names are Carl Crawford, "TB", "Outfielder", 74, 219, 25.57
# Column names are Rocco Baldelli, "TB", "Outfielder", 76, 187, 25.43
# Column names are Greg Norton, "TB", "Outfielder", 73, 200, 34.65
# Column names are Elijah Dukes, "TB", "Outfielder", 74, 220, 22.68
# Column names are Delmon Young, "TB", "Outfielder", 75, 205, 21.46
# Column names are Jonny Gomes, "TB", "Designated Hitter", 73, 205, 26.27
# Column names are Edwin Jackson, "TB", "Starting Pitcher", 75, 190, 23.47
# Column names are Scott Kazmir, "TB", "Starting Pitcher", 72, 170, 23.1
# Column names are Casey Fossum, "TB", "Starting Pitcher", 73, 160, 29.14
# Column names are Jae Seo, "TB", "Starting Pitcher", 73, 215, 29.77
# Column names are J.P. Howell, "TB", "Starting Pitcher", 72, 175, 23.85
# Column names are Tim Corcoran, "TB", "Starting Pitcher", 74, 205, 28.88
# Column names are Jason Hammel, "TB", "Starting Pitcher", 78, 200, 24.49
# Column names are James Shields, "TB", "Starting Pitcher", 76, 214, 25.19
# Column names are Brian Stokes, "TB", "Starting Pitcher", 73, 200, 27.48
# Column names are Juan Salas, "TB", "Relief Pitcher", 74, 190, 28.31
# Column names are Jeff Ridgway, "TB", "Relief Pitcher", 75, 180, 26.54
# Column names are Ruddy Lugo, "TB", "Relief Pitcher", 70, 205, 26.77
# Column names are Jae-Kuk Ryu, "TB", "Relief Pitcher", 75, 220, 23.75
# Column names are Chad Orvella, "TB", "Relief Pitcher", 71, 190, 26.41
# Column names are Dan Miceli, "TB", "Relief Pitcher", 72, 215, 36.47
# Column names are Seth McClung, "TB", "Relief Pitcher", 78, 235, 26.06
# Column names are Jon Switzer, "TB", "Relief Pitcher", 75, 191, 27.55
# Column names are Shawn Camp, "TB", "Relief Pitcher", 73, 200, 31.28
# Column names are Scott Dohmann, "TB", "Relief Pitcher", 73, 181, 29.04
# Column names are Jason LaRue, "KC", "Catcher", 71, 200, 32.95
# Column names are John Buck, "KC", "Catcher", 75, 210, 26.65
# Column names are Ryan Shealy, "KC", "First Baseman", 77, 240, 27.5
# Column names are Ross Gload, "KC", "First Baseman", 72, 185, 30.9
# Column names are Esteban German, "KC", "Second Baseman", 69, 165, 29.09
# Column names are Mark Grudzielanek, "KC", "Second Baseman", 73, 190, 36.67
# Column names are Angel Sanchez, "KC", "Second Baseman", 74, 185, 23.44
# Column names are Angel Berroa, "KC", "Shortstop", 72, 175, 29.09
# Column names are Andres Blanco, "KC", "Shortstop", 70, 155, 22.89
# Column names are Mark Teahen, "KC", "Third Baseman", 75, 210, 25.48
# Column names are Joey Gathright, "KC", "Outfielder", 70, 170, 25.84
# Column names are David DeJesus, "KC", "Outfielder", 72, 175, 27.2
# Column names are Shane Costa, "KC", "Outfielder", 72, 220, 25.22
# Column names are Mitch Maier, "KC", "Outfielder", 74, 210, 24.67
# Column names are Reggie Sanders, "KC", "Outfielder", 73, 205, 39.25
# Column names are Emil Brown, "KC", "Outfielder", 74, 200, 32.17
# Column names are Mike Sweeney, "KC", "Designated Hitter", 75, 225, 33.61
# Column names are John Bale, "KC", "Starting Pitcher", 76, 205, 32.77
# Column names are Luke Hudson, "KC", "Starting Pitcher", 75, 195, 29.83
# Column names are Scott Elarton, "KC", "Starting Pitcher", 80, 240, 31.02
# Column names are Odalis Perez, "KC", "Starting Pitcher", 72, 150, 29.73
# Column names are Gil Meche, "KC", "Starting Pitcher", 75, 200, 28.48
# Column names are Neal Musser, "KC", "Starting Pitcher", 73, 215, 26.51
# Column names are Brian Bannister, "KC", "Starting Pitcher", 74, 202, 26
# Column names are Zack Greinke, "KC", "Starting Pitcher", 74, 200, 23.36
# Column names are Jorge De La Rosa, "KC", "Starting Pitcher", 73, 190, 25.9
# Column names are Todd Wellemeyer, "KC", "Relief Pitcher", 75, 205, 28.5
# Column names are Jimmy Gobble, "KC", "Relief Pitcher", 75, 190, 25.62
# Column names are Joel Peralta, "KC", "Relief Pitcher", 71, 160, 30.94
# Column names are Ryan Braun, "KC", "Relief Pitcher", 73, 215, 26.59
# Column names are Joakim Soria, "KC", "Relief Pitcher", 75, 185, 22.78
# Column names are Ken Ray, "KC", "Relief Pitcher", 74, 200, 32.26
# Column names are David Riske, "KC", "Relief Pitcher", 74, 190, 30.35
# Column names are Octavio Dotel, "KC", "Relief Pitcher", 72, 210, 33.26
# Column names are Joe Nelson, "KC", "Relief Pitcher", 74, 185, 32.35
# Column names are Gerald Laird, "TEX", "Catcher", 74, 220, 27.3
# Column names are Miguel Ojeda, "TEX", "Catcher", 74, 190, 32.08
# Column names are Guillermo Quiroz, "TEX", "Catcher", 73, 202, 25.25
# Column names are Chris Stewart, "TEX", "Catcher", 76, 205, 25.03
# Column names are Mark Teixeira, "TEX", "First Baseman", 75, 220, 26.89
# Column names are Ian Kinsler, "TEX", "Second Baseman", 72, 175, 24.69
# Column names are Joaquin Arias, "TEX", "Shortstop", 73, 160, 22.44
# Column names are Michael Young, "TEX", "Shortstop", 73, 190, 30.36
# Column names are Hank Blalock, "TEX", "Third Baseman", 73, 200, 26.27
# Column names are Marlon Byrd, "TEX", "Outfielder", 72, 229, 29.5
# Column names are Brad Wilkerson, "TEX", "Outfielder", 72, 206, 29.75
# Column names are Sammy Sosa, "TEX", "Outfielder", 72, 220, 38.3
# Column names are Kenny Lofton, "TEX", "Outfielder", 72, 180, 39.75
# Column names are Frank Catalanotto, "TEX", "Outfielder", 71, 195, 32.84
# Column names are Nelson Cruz, "TEX", "Outfielder", 75, 175, 26.66
# Column names are Jason Botts, "TEX", "Designated Hitter", 77, 250, 26.6
# Column names are Robinson Tejeda, "TEX", "Starting Pitcher", 75, 188, 24.94
# Column names are John Rheinecker, "TEX", "Starting Pitcher", 74, 230, 27.76
# Column names are Edinson Volquez, "TEX", "Starting Pitcher", 73, 190, 23.66
# Column names are A.J. Murray, "TEX", "Starting Pitcher", 75, 200, 24.96
# Column names are Brandon McCarthy, "TEX", "Starting Pitcher", 79, 190, 23.65
# Column names are Vicente Padilla, "TEX", "Starting Pitcher", 74, 219, 29.42
# Column names are Kevin Millwood, "TEX", "Starting Pitcher", 76, 235, 32.18
# Column names are John Koronka, "TEX", "Starting Pitcher", 73, 180, 26.66
# Column names are Frank Francisco, "TEX", "Relief Pitcher", 74, 180, 27.47
# Column names are Francisco Cruceta, "TEX", "Relief Pitcher", 74, 180, 25.66
# Column names are Akinori Otsuka, "TEX", "Relief Pitcher", 72, 200, 35.13
# Column names are Eric Gagne, "TEX", "Relief Pitcher", 74, 234, 31.15
# Column names are Ron Mahay, "TEX", "Relief Pitcher", 74, 185, 35.67
# Column names are Joaquin Benoit, "TEX", "Relief Pitcher", 75, 220, 29.6
# Column names are Rick Bauer, "TEX", "Relief Pitcher", 78, 223, 30.14
# Column names are Josh Rupe, "TEX", "Relief Pitcher", 74, 200, 24.53
# Column names are Wes Littleton, "TEX", "Relief Pitcher", 74, 210, 24.49
# Column names are C.J. Wilson, "TEX", "Relief Pitcher", 74, 200, 26.28
# Column names are Scott Feldman, "TEX", "Relief Pitcher", 77, 210, 24.06
# Column names are Gregg Zaun, "TOR", "Catcher", 70, 190, 35.88
# Column names are Jason Phillips, "TOR", "Catcher", 73, 177, 30.42
# Column names are Lyle Overbay, "TOR", "First Baseman", 74, 227, 30.09
# Column names are Russ Adams, "TOR", "Second Baseman", 73, 180, 26.5
# Column names are Aaron Hill, "TOR", "Second Baseman", 71, 195, 24.94
# Column names are Jason Smith, "TOR", "Second Baseman", 75, 199, 29.6
# Column names are John McDonald, "TOR", "Shortstop", 71, 175, 32.43
# Column names are Royce Clayton, "TOR", "Shortstop", 72, 185, 37.16
# Column names are Troy Glaus, "TOR", "Third Baseman", 77, 240, 30.57
# Column names are John Hattig, "TOR", "Third Baseman", 74, 210, 27.01
# Column names are Reed Johnson, "TOR", "Outfielder", 70, 180, 30.23
# Column names are Alex Rios, "TOR", "Outfielder", 77, 194, 26.03
# Column names are Vernon Wells, "TOR", "Outfielder", 73, 225, 28.23
# Column names are Frank Thomas, "TOR", "Designated Hitter", 77, 275, 38.76
# Column names are Adam Lind, "TOR", "Designated Hitter", 74, 195, 23.62
# Column names are Shaun Marcum, "TOR", "Starting Pitcher", 72, 180, 25.21
# Column names are Casey Janssen, "TOR", "Starting Pitcher", 76, 205, 25.45
# Column names are Gustavo Chacin, "TOR", "Starting Pitcher", 71, 193, 26.24
# Column names are A.J. Burnett, "TOR", "Starting Pitcher", 76, 230, 30.15
# Column names are Roy Halladay, "TOR", "Starting Pitcher", 78, 230, 29.8
# Column names are John Thomson, "TOR", "Starting Pitcher", 75, 220, 33.41
# Column names are Tomo Ohka, "TOR", "Starting Pitcher", 73, 200, 30.95
# Column names are B.J. Ryan, "TOR", "Relief Pitcher", 78, 249, 31.17
# Column names are Scott Downs, "TOR", "Relief Pitcher", 74, 190, 30.95
# Column names are Brian Tallet, "TOR", "Relief Pitcher", 79, 208, 29.44
# Column names are Matt Roney, "TOR", "Relief Pitcher", 75, 245, 27.14
# Column names are Tracy Thorpe, "TOR", "Relief Pitcher", 76, 250, 26.21
# Column names are Jean Machi, "TOR", "Relief Pitcher", 72, 160, 24.08
# Column names are Brandon League, "TOR", "Relief Pitcher", 75, 192, 23.96
# Column names are Dustin McGowan, "TOR", "Relief Pitcher", 75, 220, 24.94
# Column names are Jason Frasor, "TOR", "Relief Pitcher", 70, 170, 29.56
# Column names are Francisco Rosario, "TOR", "Relief Pitcher", 72, 197, 26.42
# Column names are Davis Romero, "TOR", "Relief Pitcher", 70, 155, 23.92
# Column names are Jeremy Accardo, "TOR", "Relief Pitcher", 74, 190, 25.23
# Column names are Mike Redmond, "MIN", "Catcher", 71, 200, 35.82
# Column names are Joe Mauer, "MIN", "Catcher", 76, 220, 23.87
# Column names are Chris Heintz, "MIN", "Catcher", 73, 210, 32.57
# Column names are Justin Morneau, "MIN", "First Baseman", 76, 228, 25.79
# Column names are Luis Castillo, "MIN", "Second Baseman", 71, 190, 31.47
# Column names are Alexi Casilla, "MIN", "Second Baseman", 69, 160, 22.61
# Column names are Alejandro Machado, "MIN", "Second Baseman", 72, 184, 24.85
# Column names are Jason Bartlett, "MIN", "Shortstop", 72, 180, 27.33
# Column names are Luis Rodriguez, "MIN", "Third Baseman", 69, 180, 26.67
# Column names are Jeff Cirillo, "MIN", "Third Baseman", 73, 200, 37.43
# Column names are Nick Punto, "MIN", "Third Baseman", 69, 176, 29.31
# Column names are Jason Tyner, "MIN", "Outfielder", 73, 160, 29.85
# Column names are Michael Cuddyer, "MIN", "Outfielder", 74, 222, 27.93
# Column names are Torii Hunter, "MIN", "Outfielder", 74, 211, 31.62
# Column names are Lew Ford, "MIN", "Outfielder", 72, 195, 30.55
# Column names are Jason Kubel, "MIN", "Outfielder", 71, 200, 24.77
# Column names are Josh Rabe, "MIN", "Designated Hitter", 74, 210, 28.38
# Column names are Rondell White, "MIN", "Designated Hitter", 73, 225, 35.02
# Column names are Ramon Ortiz, "MIN", "Starting Pitcher", 72, 175, 33.77
# Column names are Johan Santana, "MIN", "Starting Pitcher", 72, 206, 27.97
# Column names are Carlos Silva, "MIN", "Starting Pitcher", 76, 240, 27.85
# Column names are Matt Garza, "MIN", "Starting Pitcher", 76, 185, 23.26
# Column names are Boof Bonser, "MIN", "Starting Pitcher", 76, 260, 25.38
# Column names are Francisco Liriano, "MIN", "Starting Pitcher", 74, 185, 23.35
# Column names are Scott Baker, "MIN", "Starting Pitcher", 76, 221, 25.45
# Column names are Pat Neshek, "MIN", "Relief Pitcher", 75, 205, 26.49
# Column names are Glen Perkins, "MIN", "Relief Pitcher", 71, 200, 24
# Column names are Julio DePaula, "MIN", "Relief Pitcher", 72, 170, 24.16
# Column names are Juan Rincon, "MIN", "Relief Pitcher", 71, 201, 28.1
# Column names are Jesse Crain, "MIN", "Relief Pitcher", 73, 205, 25.65
# Column names are Matt Guerrier, "MIN", "Relief Pitcher", 75, 185, 28.58
# Column names are Joe Nathan, "MIN", "Relief Pitcher", 76, 205, 32.27
# Column names are Dennys Reyes, "MIN", "Relief Pitcher", 75, 245, 29.86
# Column names are Brayan Pe?a, "ATL", "Catcher", 71, 220, 25.14
# Column names are Brian McCann, "ATL", "Catcher", 75, 210, 23.03
# Column names are Craig Wilson, "ATL", "First Baseman", 74, 220, 30.25
# Column names are Chris Woodward, "ATL", "Second Baseman", 72, 185, 30.67
# Column names are Pete Orr, "ATL", "Second Baseman", 73, 175, 27.73
# Column names are Martin Prado, "ATL", "Second Baseman", 73, 170, 23.34
# Column names are Tony Pe?a, "ATL", "Shortstop", 73, 180, 25.94
# Column names are Edgar Renteria, "ATL", "Shortstop", 73, 200, 31.56
# Column names are Chipper Jones, "ATL", "Third Baseman", 76, 210, 34.85
# Column names are Willy Aybar, "ATL", "Third Baseman", 72, 175, 23.98
# Column names are Jeff Francoeur, "ATL", "Outfielder", 76, 220, 23.14
# Column names are Matt Diaz, "ATL", "Outfielder", 73, 206, 28.99
# Column names are Kelly Johnson, "ATL", "Outfielder", 73, 180, 25.02
# Column names are Andruw Jones, "ATL", "Outfielder", 73, 210, 29.85
# Column names are Ryan Langerhans, "ATL", "Outfielder", 75, 195, 27.03
# Column names are Scott Thorman, "ATL", "Outfielder", 75, 200, 25.15
# Column names are T.J. Bohn, "ATL", "Outfielder", 77, 200, 27.12
# Column names are Tim Hudson, "ATL", "Starting Pitcher", 73, 164, 31.63
# Column names are Jonathan Johnson, "ATL", "Starting Pitcher", 72, 180, 32.62
# Column names are John Smoltz, "ATL", "Starting Pitcher", 75, 220, 39.79
# Column names are Mike Hampton, "ATL", "Starting Pitcher", 70, 195, 34.47
# Column names are Kyle Davies, "ATL", "Starting Pitcher", 74, 205, 23.47
# Column names are Chuck James, "ATL", "Starting Pitcher", 72, 170, 25.31
# Column names are Phil Stockman, "ATL", "Relief Pitcher", 80, 240, 27.1
# Column names are Macay McBride, "ATL", "Relief Pitcher", 71, 210, 24.35
# Column names are Joey Devine, "ATL", "Relief Pitcher", 71, 195, 23.45
# Column names are Peter Moylan, "ATL", "Relief Pitcher", 74, 200, 28.24
# Column names are Mike Gonzalez, "ATL", "Relief Pitcher", 74, 205, 28.77
# Column names are Lance Cormier, "ATL", "Relief Pitcher", 73, 192, 26.53
# Column names are Blaine Boyer, "ATL", "Relief Pitcher", 75, 190, 25.64
# Column names are Manny Acosta, "ATL", "Relief Pitcher", 76, 170, 25.83
# Column names are Bob Wickman, "ATL", "Relief Pitcher", 73, 240, 38.06
# Column names are Tanyon Sturtze, "ATL", "Relief Pitcher", 77, 200, 36.38
# Column names are Oscar Villarreal, "ATL", "Relief Pitcher", 72, 205, 25.27
# Column names are Rafael Soriano, "ATL", "Relief Pitcher", 73, 175, 27.2
# Column names are Chad Paronto, "ATL", "Relief Pitcher", 77, 250, 31.59
# Column names are Tyler Yates, "ATL", "Relief Pitcher", 76, 220, 29.56
# Column names are Henry Blanco, "CHC", "Catcher", 71, 224, 35.5
# Column names are Michael Barrett, "CHC", "Catcher", 75, 210, 30.35
# Column names are Geovany Soto, "CHC", "Catcher", 73, 195, 24.11
# Column names are Scott Moore, "CHC", "First Baseman", 74, 180, 23.29
# Column names are Derrek Lee, "CHC", "First Baseman", 77, 245, 31.48
# Column names are Ryan Theriot, "CHC", "Second Baseman", 71, 175, 27.23
# Column names are Ronny Cedeno, "CHC", "Shortstop", 72, 180, 24.07
# Column names are Aramis Ramirez, "CHC", "Third Baseman", 73, 215, 28.68
# Column names are Cesar Izturis, "CHC", "Third Baseman", 69, 175, 27.05
# Column names are Alfonso Soriano, "CHC", "Outfielder", 73, 180, 31.15
# Column names are Jacque Jones, "CHC", "Outfielder", 70, 195, 31.85
# Column names are Daryle Ward, "CHC", "Outfielder", 74, 230, 31.68
# Column names are Cliff Floyd, "CHC", "Outfielder", 76, 230, 34.23
# Column names are Mark DeRosa, "CHC", "Outfielder", 73, 205, 32.01
# Column names are Matt Murton, "CHC", "Outfielder", 73, 215, 25.41
# Column names are Buck Coats, "CHC", "Outfielder", 75, 195, 24.73
# Column names are Angel Pagan, "CHC", "Outfielder", 73, 180, 25.66
# Column names are Sean Marshall, "CHC", "Starting Pitcher", 79, 205, 24.5
# Column names are Carlos Marmol, "CHC", "Starting Pitcher", 74, 180, 24.38
# Column names are Ryan O'Malley, "CHC", "Starting Pitcher", 73, 190, 26.89
# Column names are Juan Mateo, "CHC", "Starting Pitcher", 74, 180, 24.2
# Column names are Rich Hill, "CHC", "Starting Pitcher", 77, 190, 26.97
# Column names are Angel Guzman, "CHC", "Starting Pitcher", 75, 190, 25.21
# Column names are Wade Miller, "CHC", "Starting Pitcher", 74, 220, 30.46
# Column names are Jason Marquis, "CHC", "Starting Pitcher", 73, 210, 28.53
# Column names are Carlos Zambrano, "CHC", "Starting Pitcher", 77, 255, 25.75
# Column names are Ted Lilly, "CHC", "Starting Pitcher", 73, 190, 31.15
# Column names are Mark Prior, "CHC", "Starting Pitcher", 77, 230, 26.48
# Column names are Neal Cotts, "CHC", "Relief Pitcher", 74, 200, 26.93
# Column names are Will Ohman, "CHC", "Relief Pitcher", 74, 205, 29.55
# Column names are Scott Eyre, "CHC", "Relief Pitcher", 73, 210, 34.75
# Column names are Kerry Wood, "CHC", "Relief Pitcher", 77, 225, 29.71
# Column names are Ryan Dempster, "CHC", "Relief Pitcher", 74, 215, 29.83
# Column names are Bob Howry, "CHC", "Relief Pitcher", 77, 220, 33.57
# Column names are Mike Wuertz, "CHC", "Relief Pitcher", 75, 205, 28.21
# Column names are Roberto Novoa, "CHC", "Relief Pitcher", 77, 200, 27.54
# Column names are Chris Snyder, "ARZ", "Catcher", 75, 220, 26.05
# Column names are Miguel Montero, "ARZ", "Catcher", 71, 197, 23.64
# Column names are Conor Jackson, "ARZ", "First Baseman", 74, 225, 24.82
# Column names are Robby Hammock, "ARZ", "First Baseman", 70, 187, 29.8
# Column names are Tony Clark, "ARZ", "First Baseman", 79, 245, 34.71
# Column names are Orlando Hudson, "ARZ", "Second Baseman", 72, 185, 29.22
# Column names are Stephen Drew, "ARZ", "Shortstop", 72, 185, 23.96
# Column names are Alberto Callaspo, "ARZ", "Shortstop", 70, 175, 23.87
# Column names are Chad Tracy, "ARZ", "Third Baseman", 74, 200, 26.77
# Column names are Chris Young, "ARZ", "Outfielder", 74, 180, 23.49
# Column names are Scott Hairston, "ARZ", "Outfielder", 72, 188, 26.77
# Column names are Carlos Quentin, "ARZ", "Outfielder", 73, 225, 24.51
# Column names are Jeff DaVanon, "ARZ", "Outfielder", 72, 200, 33.23
# Column names are Eric Byrnes, "ARZ", "Outfielder", 74, 210, 31.04
# Column names are Livan Hernandez, "ARZ", "Starting Pitcher", 74, 245, 32.02
# Column names are Doug Davis, "ARZ", "Starting Pitcher", 76, 213, 31.44
# Column names are Randy Johnson, "ARZ", "Starting Pitcher", 82, 231, 43.47
# Column names are Juan Cruz, "ARZ", "Starting Pitcher", 74, 165, 28.38
# Column names are Brandon Webb, "ARZ", "Starting Pitcher", 74, 228, 27.81
# Column names are Enrique Gonzalez, "ARZ", "Starting Pitcher", 70, 210, 24.57
# Column names are Dana Eveland, "ARZ", "Starting Pitcher", 73, 250, 23.34
# Column names are Brandon Medders, "ARZ", "Relief Pitcher", 73, 191, 27.09
# Column names are Tony Pe?a, "ARZ", "Relief Pitcher", 74, 190, 25.14
# Column names are Doug Slaten, "ARZ", "Relief Pitcher", 77, 200, 27.07
# Column names are Edgar Gonzalez, "ARZ", "Relief Pitcher", 72, 215, 24.02
# Column names are Jose Valverde, "ARZ", "Relief Pitcher", 76, 254, 27.6
# Column names are Jorge Julio, "ARZ", "Relief Pitcher", 73, 232, 27.99
# Column names are Brandon Lyon, "ARZ", "Relief Pitcher", 73, 180, 27.56
# Column names are Miguel Olivo, "FLA", "Catcher", 72, 215, 28.63
# Column names are Matt Treanor, "FLA", "Catcher", 74, 220, 30.99
# Column names are Mike Jacobs, "FLA", "First Baseman", 74, 180, 26.33
# Column names are Dan Uggla, "FLA", "Second Baseman", 71, 200, 26.97
# Column names are Robert Andino, "FLA", "Shortstop", 72, 170, 22.85
# Column names are Hanley Ramirez, "FLA", "Shortstop", 75, 195, 23.19
# Column names are Miguel Cabrera, "FLA", "Third Baseman", 74, 210, 23.87
# Column names are Aaron Boone, "FLA", "Third Baseman", 74, 200, 33.98
# Column names are Joe Borchard, "FLA", "Outfielder", 77, 220, 28.26
# Column names are Alfredo Amezaga, "FLA", "Outfielder", 70, 165, 29.12
# Column names are Cody Ross, "FLA", "Outfielder", 71, 180, 26.18
# Column names are Josh Willingham, "FLA", "Outfielder", 73, 200, 28.03
# Column names are Jeremy Hermida, "FLA", "Outfielder", 76, 200, 23.08
# Column names are Eric Reed, "FLA", "Outfielder", 71, 170, 26.24
# Column names are Reggi Abercrombie, "FLA", "Outfielder", 75, 224, 26.63
# Column names are Ricky Nolasco, "FLA", "Starting Pitcher", 74, 220, 24.21
# Column names are Anibal Sanchez, "FLA", "Starting Pitcher", 72, 180, 23.01
# Column names are Scott Olsen, "FLA", "Starting Pitcher", 76, 198, 23.13
# Column names are Josh Johnson, "FLA", "Starting Pitcher", 79, 240, 23.08
# Column names are Dontrelle Willis, "FLA", "Starting Pitcher", 76, 239, 25.13
# Column names are Logan Kensing, "FLA", "Relief Pitcher", 73, 185, 24.66
# Column names are Sergio Mitre, "FLA", "Relief Pitcher", 76, 210, 26.03
# Column names are Kevin Gregg, "FLA", "Relief Pitcher", 78, 220, 28.7
# Column names are Travis Bowyer, "FLA", "Relief Pitcher", 75, 200, 25.57
# Column names are Renyel Pinto, "FLA", "Relief Pitcher", 76, 195, 24.65
# Column names are Randy Messenger, "FLA", "Relief Pitcher", 72, 220, 25.55
# Column names are Yusmeiro Petit, "FLA", "Relief Pitcher", 72, 230, 22.27
# Column names are Carlos Martinez, "FLA", "Relief Pitcher", 73, 170, 24.76
# Column names are Taylor Tankersley, "FLA", "Relief Pitcher", 73, 220, 23.98
# Column names are Henry Owens, "FLA", "Relief Pitcher", 75, 230, 27.85
# Column names are Jose Garcia, "FLA", "Relief Pitcher", 71, 165, 22.14
# Column names are Matt Lindstrom, "FLA", "Relief Pitcher", 76, 205, 27.05
# Column names are Javier Valentin, "CIN", "Catcher", 70, 192, 31.45
# Column names are Chad Moeller, "CIN", "Catcher", 75, 210, 32.03
# Column names are David Ross, "CIN", "Catcher", 74, 205, 29.95
# Column names are Joey Votto, "CIN", "First Baseman", 75, 200, 23.47
# Column names are Scott Hatteberg, "CIN", "First Baseman", 73, 210, 37.21
# Column names are Brandon Phillips, "CIN", "Second Baseman", 71, 185, 25.67
# Column names are Juan Castro, "CIN", "Shortstop", 71, 195, 34.69
# Column names are Alex Gonzalez, "CIN", "Shortstop", 72, 202, 30.04
# Column names are Mark Bellhorn, "CIN", "Third Baseman", 73, 205, 32.52
# Column names are Edwin Encarnacion, "CIN", "Third Baseman", 73, 195, 24.15
# Column names are Jeff Keppinger, "CIN", "Third Baseman", 72, 180, 26.86
# Column names are Norris Hopper, "CIN", "Outfielder", 69, 200, 27.94
# Column names are Chris Denorfia, "CIN", "Outfielder", 73, 185, 26.63
# Column names are Adam Dunn, "CIN", "Outfielder", 78, 240, 27.31
# Column names are Bubba Crosby, "CIN", "Outfielder", 71, 185, 30.55
# Column names are Jeff Conine, "CIN", "Outfielder", 73, 220, 40.68
# Column names are Ken Griffey Jr., "CIN", "Outfielder", 75, 205, 37.27
# Column names are Josh Hamilton, "CIN", "Outfielder", 76, 205, 25.78
# Column names are Ryan Freel, "CIN", "Outfielder", 70, 180, 30.98
# Column names are Kyle Lohse, "CIN", "Starting Pitcher", 74, 201, 28.41
# Column names are Bronson Arroyo, "CIN", "Starting Pitcher", 77, 190, 30.01
# Column names are Eric Milton, "CIN", "Starting Pitcher", 75, 208, 31.57
# Column names are Aaron Harang, "CIN", "Starting Pitcher", 79, 240, 28.81
# Column names are Kirk Saarloos, "CIN", "Starting Pitcher", 72, "", 27.77
# Column names are Elizardo Ramirez, "CIN", "Starting Pitcher", 72, 180, 24.09
# Column names are Todd Coffey, "CIN", "Relief Pitcher", 77, 230, 26.47
# Column names are Brian Shackelford, "CIN", "Relief Pitcher", 73, 195, 30.5
# Column names are Bill Bray, "CIN", "Relief Pitcher", 75, 215, 23.74
# Column names are Bobby Livingston, "CIN", "Relief Pitcher", 75, 190, 24.49
# Column names are Matt Belisle, "CIN", "Relief Pitcher", 75, 195, 26.73
# Column names are Gary Majewski, "CIN", "Relief Pitcher", 73, 215, 27.01
# Column names are Mike Stanton, "CIN", "Relief Pitcher", 73, 215, 39.75
# Column names are Brad Salmon, "CIN", "Relief Pitcher", 76, 220, 27.16
# Column names are Jared Burton, "CIN", "Relief Pitcher", 77, 220, 25.74
# Column names are David Weathers, "CIN", "Relief Pitcher", 75, 230, 37.43
# Column names are Rheal Cormier, "CIN", "Relief Pitcher", 70, 195, 39.85
# Column names are Yorvit Torrealba, "COL", "Catcher", 71, 190, 28.62
# Column names are Chris Iannetta, "COL", "Catcher", 71, 195, 23.9
# Column names are Alvin Colina, "COL", "Catcher", 75, 209, 25.18
# Column names are Todd Helton, "COL", "First Baseman", 74, 204, 33.53
# Column names are Jamey Carroll, "COL", "Second Baseman", 69, 170, 33.03
# Column names are Kaz Matsui, "COL", "Second Baseman", 70, 185, 31.35
# Column names are Troy Tulowitzki, "COL", "Shortstop", 75, 205, 22.39
# Column names are Clint Barmes, "COL", "Shortstop", 72, 175, 27.99
# Column names are Garrett Atkins, "COL", "Third Baseman", 75, 210, 27.22
# Column names are Ryan Spilborghs, "COL", "Outfielder", 73, 190, 27.49
# Column names are Cory Sullivan, "COL", "Outfielder", 72, 180, 27.53
# Column names are Jeff Salazar, "COL", "Outfielder", 72, 180, 26.26
# Column names are Willy Taveras, "COL", "Outfielder", 72, 160, 25.18
# Column names are Matt Holliday, "COL", "Outfielder", 76, 235, 27.12
# Column names are Brad Hawpe, "COL", "Outfielder", 75, 200, 27.69
# Column names are Jeff Baker, "COL", "Outfielder", 74, 210, 25.69
# Column names are Javy Lopez, "COL", "Designated Hitter", 75, 224, 36.32
# Column names are Byung-Hyun Kim, "COL", "Starting Pitcher", 69, 180, 28.11
# Column names are Rodrigo Lopez, "COL", "Starting Pitcher", 73, 190, 31.21
# Column names are Brian Lawrence, "COL", "Starting Pitcher", 72, 197, 30.8
# Column names are Josh Fogg, "COL", "Starting Pitcher", 72, 203, 30.21
# Column names are Aaron Cook, "COL", "Starting Pitcher", 75, 205, 28.06
# Column names are Denny Bautista, "COL", "Starting Pitcher", 77, 170, 26.52
# Column names are Ubaldo Jimenez, "COL", "Starting Pitcher", 76, 200, 23.1
# Column names are Jason Hirsh, "COL", "Starting Pitcher", 80, 250, 25.02
# Column names are Jeff Francis, "COL", "Starting Pitcher", 77, 200, 26.14
# Column names are Taylor Buchholz, "COL", "Starting Pitcher", 76, 220, 25.38
# Column names are Ryan Speier, "COL", "Relief Pitcher", 79, 200, 27.6
# Column names are Ramon Ramirez, "COL", "Relief Pitcher", 71, 190, 25.5
# Column names are Manny Corpas, "COL", "Relief Pitcher", 75, 170, 24.24
# Column names are Juan Morillo, "COL", "Relief Pitcher", 73, 190, 23.32
# ...
# Column names are Shane Victorino, "PHI", "Outfielder", 69, 160, 26.25
# Column names are Aaron Rowand, "PHI", "Outfielder", 72, 205, 29.5
# Column names are Pat Burrell, "PHI", "Outfielder", 76, 223, 30.39
# Column names are Greg Dobbs, "PHI", "Designated Hitter", 73, 205, 28.66
# Column names are Cole Hamels, "PHI", "Starting Pitcher", 75, 175, 23.18
# Column names are Alfredo Simon, "PHI", "Starting Pitcher", 76, 170, 25.81
# Column names are Scott Mathieson, "PHI", "Starting Pitcher", 75, 190, 23.01
# Column names are Freddy Garcia, "PHI", "Starting Pitcher", 76, 240, 31.72
# Column names are Jamie Moyer, "PHI", "Starting Pitcher", 72, 175, 44.28
# Column names are Jon Lieber, "PHI", "Starting Pitcher", 74, 230, 36.91
# Column names are Brett Myers, "PHI", "Starting Pitcher", 76, 223, 26.54
# Column names are Adam Eaton, "PHI", "Starting Pitcher", 74, 196, 29.27
# Column names are Geoff Geary, "PHI", "Relief Pitcher", 72, 167, 30.51
# Column names are Clay Condrey, "PHI", "Relief Pitcher", 75, 195, 31.28
# Column names are Ryan Madson, "PHI", "Relief Pitcher", 78, 190, 26.51
# Column names are Antonio Alfonseca, "PHI", "Relief Pitcher", 77, 250, 34.87
# Column names are Tom Gordon, "PHI", "Relief Pitcher", 70, 190, 39.28
# Column names are Brian Sanches, "PHI", "Relief Pitcher", 72, 190, 28.56
# Column names are Jim Ed Warden, "PHI", "Relief Pitcher", 79, 190, 27.82
# Column names are Anderson Garcia, "PHI", "Relief Pitcher", 74, 170, 25.94
# Column names are Eude Brito, "PHI", "Relief Pitcher", 71, 160, 28.53
# Column names are Fabio Castro, "PHI", "Relief Pitcher", 68, 150, 22.11
# Column names are Matt Smith, "PHI", "Relief Pitcher", 77, 225, 27.71
# Column names are Damian Miller, "MLW", "Catcher", 75, 220, 37.38
# Column names are Johnny Estrada, "MLW", "Catcher", 71, 209, 30.67
# Column names are Mike Rivera, "MLW", "Catcher", 72, 210, 30.48
# Column names are J.D. Closser, "MLW", "Catcher", 70, 176, 27.12
# Column names are Prince Fielder, "MLW", "First Baseman", 72, 260, 22.81
# Column names are Rickie Weeks, "MLW", "Second Baseman", 72, 195, 24.46
# Column names are Tony Graffanino, "MLW", "Second Baseman", 73, 190, 34.73
# Column names are Craig Counsell, "MLW", "Shortstop", 72, 184, 36.53
# Column names are J.J. Hardy, "MLW", "Shortstop", 74, 180, 24.53
# Column names are Bill Hall, "MLW", "Shortstop", 72, 195, 27.17
# Column names are Vinny Rottino, "MLW", "Third Baseman", 72, 195, 26.9
# Column names are Corey Koskie, "MLW", "Third Baseman", 75, 219, 33.67
# Column names are Kevin Mench, "MLW", "Outfielder", 72, 225, 29.14
# Column names are Geoff Jenkins, "MLW", "Outfielder", 73, 212, 32.61
# Column names are Brady Clark, "MLW", "Outfielder", 74, 202, 33.87
# Column names are Tony Gwynn Jr., "MLW", "Outfielder", 72, 185, 24.41
# Column names are Corey Hart, "MLW", "Outfielder", 78, 200, 24.94
# Column names are Gabe Gross, "MLW", "Outfielder", 75, 209, 27.36
# Column names are Laynce Nix, "MLW", "Outfielder", 72, 200, 26.33
# Column names are Drew Anderson, "MLW", "Outfielder", 74, 195, 25.72
# Column names are Claudio Vargas, "MLW", "Starting Pitcher", 75, 228, 28.7
# Column names are Chris Capuano, "MLW", "Starting Pitcher", 75, 210, 28.53
# Column names are Ben Hendrickson, "MLW", "Starting Pitcher", 76, 190, 26.07
# Column names are Dave Bush, "MLW", "Starting Pitcher", 74, 212, 27.31
# Column names are Carlos Villanueva, "MLW", "Starting Pitcher", 74, 190, 23.26
# Column names are Ben Sheets, "MLW", "Starting Pitcher", 73, 218, 28.62
# Column names are Jeff Suppan, "MLW", "Starting Pitcher", 74, 220, 32.16
# Column names are Brian Shouse, "MLW", "Relief Pitcher", 71, 190, 38.43
# Column names are Francisco Cordero, "MLW", "Relief Pitcher", 74, 235, 31.81
# Column names are Derrick Turnbow, "MLW", "Relief Pitcher", 75, 210, 29.1
# Column names are Matt Wise, "MLW", "Relief Pitcher", 76, 200, 31.28
# Column names are Grant Balfour, "MLW", "Relief Pitcher", 74, 188, 29.17
# Column names are Dennis Sarfate, "MLW", "Relief Pitcher", 76, 210, 25.89
# Column names are Jose Capellan, "MLW", "Relief Pitcher", 76, 235, 26.13
# Column names are Greg Aquino, "MLW", "Relief Pitcher", 73, 188, 29.13
# Column names are Josh Bard, "SD", "Catcher", 75, 215, 28.92
# Column names are Rob Bowen, "SD", "Catcher", 75, 216, 26.01
# Column names are Adrian Gonzalez, "SD", "First Baseman", 74, 220, 24.81
# Column names are Marcus Giles, "SD", "Second Baseman", 68, 180, 28.79
# Column names are Todd Walker, "SD", "Second Baseman", 72, 185, 33.77
# Column names are Geoff Blum, "SD", "Shortstop", 75, 200, 33.85
# Column names are Khalil Greene, "SD", "Shortstop", 71, 210, 27.36
# Column names are Paul McAnulty, "SD", "Outfielder", 70, 220, 26.01
# Column names are Terrmel Sledge, "SD", "Outfielder", 72, 185, 29.95
# Column names are Jack Cust, "SD", "Outfielder", 73, 231, 28.12
# Column names are Jose Cruz Jr., "SD", "Outfielder", 72, 210, 32.87
# Column names are Russell Branyan, "SD", "Outfielder", 75, 195, 31.2
# Column names are Mike Cameron, "SD", "Outfielder", 74, 200, 34.14
# Column names are Brian Giles, "SD", "Outfielder", 70, 205, 36.11
# Column names are Kevin Kouzmanoff, "SD", "Designated Hitter", 73, 200, 25.6
# Column names are Mike Thompson, "SD", "Starting Pitcher", 76, 200, 26.31
# Column names are Clay Hensley, "SD", "Starting Pitcher", 71, 190, 27.5
# Column names are Chris Young, "SD", "Starting Pitcher", 82, 250, 27.77
# Column names are Greg Maddux, "SD", "Starting Pitcher", 72, 185, 40.88
# Column names are Jake Peavy, "SD", "Starting Pitcher", 73, 180, 25.75
# Column names are Scott Cassidy, "SD", "Relief Pitcher", 74, 170, 31.41
# Column names are Scott Strickland, "SD", "Relief Pitcher", 71, 180, 30.84
# Column names are Scott Linebrink, "SD", "Relief Pitcher", 75, 208, 30.57
# Column names are Doug Brocail, "SD", "Relief Pitcher", 77, 235, 39.79
# Column names are Trevor Hoffman, "SD", "Relief Pitcher", 72, 215, 39.38
# Column names are Heath Bell, "SD", "Relief Pitcher", 74, 244, 29.42
# Column names are Royce Ring, "SD", "Relief Pitcher", 72, 220, 26.19
# Column names are Cla Meredith, "SD", "Relief Pitcher", 73, 185, 23.74
# Column names are Andrew Brown, "SD", "Relief Pitcher", 78, 230, 26.03
# Column names are Mike Adams, "SD", "Relief Pitcher", 77, 190, 28.59
# Column names are Justin Hampson, "SD", "Relief Pitcher", 73, 200, 26.77
# Column names are Kevin Cameron, "SD", "Relief Pitcher", 73, 180, 27.21
# Column names are Ryan Ketchner, "SD", "Relief Pitcher", 73, 190, 24.87
# Column names are Brian Schneider, "WAS", "Catcher", 73, 196, 30.26
# Column names are Jesus Flores, "WAS", "Catcher", 73, 180, 22.34
# Column names are Larry Broadway, "WAS", "First Baseman", 76, 230, 26.2
# Column names are Nick Johnson, "WAS", "First Baseman", 75, 224, 28.45
# Column names are Bernie Castro, "WAS", "Second Baseman", 70, 160, 27.63
# Column names are Josh Wilson, "WAS", "Shortstop", 73, 178, 25.93
# Column names are Cristian Guzman, "WAS", "Shortstop", 72, 205, 28.94
# Column names are Felipe Lopez, "WAS", "Shortstop", 73, 185, 26.8
# Column names are Ryan Zimmerman, "WAS", "Third Baseman", 75, 210, 22.42
# Column names are Nook Logan, "WAS", "Outfielder", 74, 180, 27.26
# Column names are Ryan Church, "WAS", "Outfielder", 73, 190, 28.38
# Column names are Kory Casto, "WAS", "Outfielder", 73, 200, 25.23
# Column names are Mike Restovich, "WAS", "Outfielder", 76, 257, 28.16
# Column names are Alex Escobar, "WAS", "Outfielder", 73, 190, 28.48
# Column names are Austin Kearns, "WAS", "Outfielder", 75, 220, 26.78
# Column names are Chris Snelling, "WAS", "Outfielder", 70, 165, 25.24
# Column names are Billy Traber, "WAS", "Starting Pitcher", 77, 205, 27.45
# Column names are Tim Redding, "WAS", "Starting Pitcher", 72, 200, 29.05
# Column names are John Patterson, "WAS", "Starting Pitcher", 77, 208, 29.08
# Column names are Shawn Hill, "WAS", "Starting Pitcher", 74, 185, 25.84
# Column names are Joel Hanrahan, "WAS", "Starting Pitcher", 75, 215, 25.4
# Column names are Mike O'Connor, "WAS", "Starting Pitcher", 75, 170, 26.54
# Column names are Emiliano Fruto, "WAS", "Relief Pitcher", 75, 235, 22.73
# Column names are Chris Schroder, "WAS", "Relief Pitcher", 75, 210, 28.53
# Column names are Brett Campbell, "WAS", "Relief Pitcher", 72, 170, 25.37
# Column names are Beltran Perez, "WAS", "Relief Pitcher", 74, 180, 25.35
# Column names are Levale Speigner, "WAS", "Relief Pitcher", 71, 170, 26.43
# Column names are Jason Bergmann, "WAS", "Relief Pitcher", 76, 190, 25.43
# Column names are Saul Rivera, "WAS", "Relief Pitcher", 71, 150, 29.23
# Column names are Chris Booker, "WAS", "Relief Pitcher", 75, 230, 30.22
# Column names are Micah Bowie, "WAS", "Relief Pitcher", 76, 203, 32.3
# Column names are Jon Rauch, "WAS", "Relief Pitcher", 83, 260, 28.42
# Column names are Jerome Williams, "WAS", "Relief Pitcher", 75, 246, 25.24
# Column names are Luis Ayala, "WAS", "Relief Pitcher", 74, 186, 29.13
# Column names are Ryan Wagner, "WAS", "Relief Pitcher", 76, 210, 24.63
# Column names are Chad Cordero, "WAS", "Relief Pitcher", 72, 198, 24.95
# Column names are Humberto Cota, "PIT", "Catcher", 72, 210, 28.06
# Column names are Ronny Paulino, "PIT", "Catcher", 75, 215, 25.86
# Column names are Adam LaRoche, "PIT", "First Baseman", 75, 180, 27.32
# Column names are Ryan Doumit, "PIT", "First Baseman", 72, 200, 25.91
# Column names are Brad Eldred, "PIT", "First Baseman", 77, 245, 26.63
# Column names are Jose Castillo, "PIT", "Second Baseman", 73, 200, 25.95
# Column names are Jack Wilson, "PIT", "Shortstop", 72, 192, 29.17
# Column names are Freddy Sanchez, "PIT", "Third Baseman", 70, 192, 29.19
# Column names are Jason Bay, "PIT", "Outfielder", 74, 200, 28.44
# Column names are Jose Bautista, "PIT", "Outfielder", 72, 192, 26.36
# Column names are Xavier Nady, "PIT", "Outfielder", 74, 205, 28.29
# Column names are Jody Gerut, "PIT", "Outfielder", 72, 190, 29.45
# Column names are Nate McLouth, "PIT", "Outfielder", 71, 186, 25.34
# Column names are Chris Duffy, "PIT", "Outfielder", 70, 170, 26.86
# Column names are Rajai Davis, "PIT", "Outfielder", 71, 197, 26.36
# Column names are Shane Youman, "PIT", "Starting Pitcher", 76, 219, 27.39
# Column names are Yoslan Herrera, "PIT", "Starting Pitcher", 74, 200, 25.84
# Column names are Josh Shortslef, "PIT", "Starting Pitcher", 76, 220, 25.08
# Column names are Zach Duke, "PIT", "Starting Pitcher", 74, 207, 23.87
# Column names are Paul Maholm, "PIT", "Starting Pitcher", 74, 225, 24.68
# Column names are Tom Gorzelanny, "PIT", "Starting Pitcher", 74, 207, 24.64
# Column names are Shawn Chacon, "PIT", "Starting Pitcher", 75, 212, 29.19
# Column names are Tony Armas Jr., "PIT", "Starting Pitcher", 75, 225, 28.84
# Column names are Ian Snell, "PIT", "Starting Pitcher", 71, 170, 25.33
# Column names are Sean Burnett, "PIT", "Starting Pitcher", 71, 190, 24.45
# Column names are John Grabow, "PIT", "Relief Pitcher", 74, 210, 28.32
# Column names are Marty McLeary, "PIT", "Relief Pitcher", 77, 230, 32.34
# Column names are Salomon Torres, "PIT", "Relief Pitcher", 71, 210, 34.97
# Column names are Damaso Marte, "PIT", "Relief Pitcher", 74, 200, 32.04
# Column names are Matt Capps, "PIT", "Relief Pitcher", 75, 238, 23.49
# Column names are Josh Sharpless, "PIT", "Relief Pitcher", 77, 234, 26.09
# Column names are Bryan Bullington, "PIT", "Relief Pitcher", 76, 222, 26.41
# Column names are Jonah Bayliss, "PIT", "Relief Pitcher", 74, 200, 26.55
# Column names are Brian Rogers, "PIT", "Relief Pitcher", 76, 190, 24.62
# Column names are Juan Perez, "PIT", "Relief Pitcher", 72, 170, 28.49
# Column names are Bengie Molina, "SF", "Catcher", 71, 220, 32.61
# Column names are Eliezer Alfonzo, "SF", "Catcher", 72, 223, 28.06
# Column names are Lance Niekro, "SF", "First Baseman", 75, 210, 28.08
# Column names are Mark Sweeney, "SF", "First Baseman", 73, 215, 37.34
# Column names are Ray Durham, "SF", "Second Baseman", 68, 196, 35.25
# Column names are Kevin Frandsen, "SF", "Second Baseman", 72, 175, 24.77
# Column names are Omar Vizquel, "SF", "Shortstop", 69, 175, 39.85
# Column names are Rich Aurilia, "SF", "Third Baseman", 73, 189, 35.49
# Column names are Pedro Feliz, "SF", "Third Baseman", 73, 205, 31.84
# Column names are Todd Linden, "SF", "Outfielder", 75, 210, 26.67
# Column names are Dave Roberts, "SF", "Outfielder", 70, 180, 34.75
# Column names are Jason Ellison, "SF", "Outfielder", 70, 180, 28.91
# Column names are Randy Winn, "SF", "Outfielder", 74, 197, 32.73
# Column names are Ryan Klesko, "SF", "Outfielder", 75, 220, 35.72
# Column names are Barry Bonds, "SF", "Outfielder", 74, 228, 42.6
# Column names are Fred Lewis, "SF", "Outfielder", 74, 190, 26.22
# Column names are Kelyn Acosta, "SF", "Starting Pitcher", 73, 204, 21.85
# Column names are Jonathan Sanchez, "SF", "Starting Pitcher", 74, 165, 24.28
# Column names are Matt Cain, "SF", "Starting Pitcher", 75, 216, 22.41
# Column names are Matt Morris, "SF", "Starting Pitcher", 77, 220, 32.56
# Column names are Russ Ortiz, "SF", "Starting Pitcher", 73, 208, 32.74
# Column names are Noah Lowry, "SF", "Starting Pitcher", 74, 210, 26.39
# Column names are Barry Zito, "SF", "Starting Pitcher", 76, 215, 28.8
# Column names are Vinnie Chulk, "SF", "Relief Pitcher", 74, 195, 28.2
# Column names are Kevin Correia, "SF", "Relief Pitcher", 75, 200, 26.52
# Column names are Steve Kline, "SF", "Relief Pitcher", 73, 215, 34.52
# Column names are Armando Benitez, "SF", "Relief Pitcher", 76, 229, 34.32
# Column names are Scott Munter, "SF", "Relief Pitcher", 78, 240, 26.98
# Column names are Jack Taschner, "SF", "Relief Pitcher", 75, 207, 28.86
# Column names are Brian Wilson, "SF", "Relief Pitcher", 73, 205, 24.96
# Column names are Merkin Valdez, "SF", "Relief Pitcher", 77, 208, 25.3
# Column names are Brad Hennessey, "SF", "Relief Pitcher", 74, 185, 27.06
# Column names are Billy Sadler, "SF", "Relief Pitcher", 72, 190, 25.44
# Column names are Pat Misch, "SF", "Relief Pitcher", 74, 170, 25.53
# Column names are Gary Bennett, "STL", "Catcher", 72, 208, 34.87
# Column names are Yadier Molina, "STL", "Catcher", 71, 225, 24.63
# Column names are John Nelson, "STL", "First Baseman", 73, 190, 27.99
# Column names are Albert Pujols, "STL", "First Baseman", 75, 225, 27.12
# Column names are Adam Kennedy, "STL", "Second Baseman", 73, 185, 31.14
# Column names are Aaron Miles, "STL", "Second Baseman", 67, 180, 30.21
# Column names are David Eckstein, "STL", "Shortstop", 67, 165, 32.11
# Column names are Scott Rolen, "STL", "Third Baseman", 76, 240, 31.91
# Column names are Scott Spiezio, "STL", "Third Baseman", 74, 220, 34.44
# Column names are Jim Edmonds, "STL", "Outfielder", 73, 212, 36.68
# Column names are So Taguchi, "STL", "Outfielder", 70, 163, 37.66
# Column names are Juan Encarnacion, "STL", "Outfielder", 75, 215, 30.98
# Column names are Skip Schumaker, "STL", "Outfielder", 70, 175, 27.07
# Column names are John Rodriguez, "STL", "Outfielder", 72, 205, 29.11
# Column names are Chris Duncan, "STL", "Outfielder", 77, 210, 25.82
# Column names are Adam Wainwright, "STL", "Starting Pitcher", 79, 205, 25.5
# Column names are Mark Mulder, "STL", "Starting Pitcher", 78, 208, 29.57
# Column names are Anthony Reyes, "STL", "Starting Pitcher", 74, 215, 25.37
# Column names are Ryan Franklin, "STL", "Starting Pitcher", 75, 180, 33.99
# Column names are Kip Wells, "STL", "Starting Pitcher", 75, 200, 29.86
# Column names are Chris Carpenter, "STL", "Starting Pitcher", 78, 230, 31.84
# Column names are Russ Springer, "STL", "Relief Pitcher", 76, 211, 38.31
# Column names are Jason Isringhausen, "STL", "Relief Pitcher", 75, 230, 34.48
# Column names are Ricardo Rincon, "STL", "Relief Pitcher", 69, 190, 36.88
# Column names are Braden Looper, "STL", "Relief Pitcher", 75, 220, 32.34
# Column names are Randy Flores, "STL", "Relief Pitcher", 72, 180, 31.58
# Column names are Josh Hancock, "STL", "Relief Pitcher", 75, 205, 28.89
# Column names are Brad Thompson, "STL", "Relief Pitcher", 73, 190, 25.08
# Column names are Tyler Johnson, "STL", "Relief Pitcher", 74, 180, 25.73
# Column names are Chris Narveson, "STL", "Relief Pitcher", 75, 205, 25.19
# Column names are Randy Keisler, "STL", "Relief Pitcher", 75, 190, 31.01
# Column names are Josh Kinney, "STL", "Relief Pitcher", 73, 195, 27.92
# Column names are

# %% [markdown]
# In the above code, we have opened 'python.csv' using the **open()** function. We used **csv.reader()** function to read the file, that returns an iterable reader object. The reader object have consisted the data and we iterated using for loop to print the content of each row

# %% [markdown]
# We can also use **DictReader()** function to read the csv file directly into a dictionary rather than deal with a list of individual string eleme

# %%
import csv
with open('sample2.csv') as csv_file:
    csv_reader=csv.DictReader(csv_file)
    print(f'{csv_reader} of type {type(csv_reader)}')
    
    for row in csv_reader:
        print(f'Column names are {",".join(row)}')
# Out:
# <csv.DictReader object at 0x000001A1AC273EE0> of type <class 'csv.DictReader'>
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# ...
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"
# Column names are Name, "Team", "Position", "Height(inches)", "Weight(lbs)", "Age"

# %% [markdown]
# FOR easiness and better readabilty use PANDAS and numpy

# %%
# import pandas
# df=pandas.read_csv('sample2.csv')
# # print(df)

# %% [markdown]
# #CSV write

# %%
import csv    
     
with open('new.csv', 'w') as csvfile:    
    fieldnames = ['first_name', 'last_name', 'Rank']    
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)    
     
    writer.writeheader()    
    writer.writerow({'Rank': 'B', 'first_name': 'Parker', 'last_name': 'Brian'})    
    writer.writerow({'Rank': 'A', 'first_name': 'Smith',    
                     'last_name': 'Rodriguez'})    
    writer.writerow({'Rank': 'B', 'first_name': 'Jane', 'last_name': 'Oscar'})    
    writer.writerow({'Rank': 'B', 'first_name': 'Jane', 'last_name': 'Loive'})    
     
print("Writing complete")
# Out:
# Writing complete
