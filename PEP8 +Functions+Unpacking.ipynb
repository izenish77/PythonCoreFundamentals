# %% [markdown]
# #*First Assignment on Core Fundamentals of Python

# %% [markdown]
# **_Task:_**

# %% [markdown]
# https://www.figma.com/file/Skamra6jHy57vDrvNMTK4X/Python-Internship?node-id=0%3A1

# %% [markdown]
# ##PEP -> Python Enterprise Proposal is a document that provides guidelines on
# how to write readable code.

# %% [markdown]
# **__Function        ->        function, my_function
# Variable        ->        x, var, my_variable
# Class           ->        Model, MyClass
# Method          ->        class_method, method
# Constant        ->        CONSTANT, MY_CONSTANT, MY_LONG_C‐ONSTANT
# Module          ->        module.py, my_mod‐ule.py
# Package         ->        package, mypackage __**

# %%
class LearningPep:
    def my_function(self,x,var,my_variable):
        self.x="Small alphabets"
        self.var="small words"
        self.my_variable="words seperated by _"
        
    def function(self,x,y,z):
        self.my_function(x,y,z)
        print(f'a function name should either be {self.x}\n or {self.var} \n or {self.my_variable}')

NAME='Jenish'
MY_AGE=22
MY_LAST_NAME="Prajapati"
obj1=LearningPep()
obj1.function(NAME,MY_AGE,MY_LAST_NAME)
# Out:
# a function name should either be Small alphabets
#  or small words
#  or words seperated by _

# %% [markdown]
# *Naming conventions
# Never use l, O, or I single letter names as
# these can be mistaken for 1 and 0,
# depending on typeface*

# %% [markdown]
# Comments
# Limit the line length of
# comments and
# docstrings to 72
# characters.
# Use complete
# sentences, starting
# with a capital
# letter.
# Make sure to update
# comments if you
# change your code.

# %% [markdown]
# Refer to the following PEP 8 cheetsheet:
# http://bitly.bz/RHQea

# %% [markdown]
# #FUNCTIONS

# %%
def function(a=1,b,c):  #once a default value is initiated then the rest of the arguments must contain default values
    print(a,b,c)
# Out:
#   Input In [12]
#     def function(a=1,b,c):  #once a default value is initiated then the rest of the arguments must contain default values
#                        ^
# SyntaxError: non-default argument follows default argument

# %% [markdown]
# _Keyword Arguments(named arguments)
# Positional arguments, can optionally be specified usign their corresponding parameter name.
# This allows is to pass the arguments without using the postitional assignment _

# %%
def my_fun(a,b,c=3):
    print("a={0},b={1},c={2}".format(a,b,c))

my_fun(c=99,b=22,a=3)
# Out:
# a=3,b=22,c=99

# %% [markdown]
# Note that once a keyword argument has been used, all arguments thereafter must also be named:

# %% [markdown]
# #Extended unpacking

# %%
l=[1,2,3,4,5,6]
a=l[0]
b=l[1:]

#this can also be achieved by * symbol
c,*d=l
print(f'a is {a} b is {b} \n c is {c} and d is {d}')
# Out:
# a is 1 b is [2, 3, 4, 5, 6]
#  c is 1 and d is [2, 3, 4, 5, 6]

# %%
NAME="JENISH"
a,b,*c,d=NAME
print(f'a is {a}\n b is {b} \n c is {c} \nand d is {d}')
# Out:
# a is J
#  b is E
#  c is ['N', 'I', 'S']
# and d is H

# %%
type(c)
# Out:
# list

# %% [markdown]
# **We can also use unpacking at the left hand side of the object**

# %%
x=['J','E','N']
y=["i","s",'h']
MYNAME=[*x,*y]
print(MYNAME)
# Out:
# ['J', 'E', 'N', 'i', 's', 'h']

# %% [markdown]
# ###-> * for dictionaries only works for keys inorder to upack both key value pair use **

# %% [markdown]
# ##*args as parameters in functions
# as we've previously seen args hold previously locked variables
# We can use a similar concept in function definitions to allow for arbitrary numbers of positional parameters/arguments:

# %%
def function(a,b,*args):
    print(a)
    print(b)
    print(args)
function(1,2,3,4,5,6,7,8)
# Out:
# 1
# 2
# (3, 4, 5, 6, 7, 8)

# %% [markdown]
# **unlike normal unpacking
# *args returns tuple not a list
# args can be anykeyword that you wish**

# %%
def func1(a, b, c, *d):
    print(a)
    print(b)
    print(c)
    print(d)
func1(10, c=20, b=10, 'a', 'b')
# Out:
#   Input In [21]
#     func1(10, c=20, b=10, 'a', 'b')
#                                   ^
# SyntaxError: positional argument follows keyword argument

# %% [markdown]
# **_ once a keyword argument is used in a function call, we cannot use positional arguments after that._**

# %% [markdown]
# Using a named argument is optional and up to the caller.
#
# What if we wanted to force calls to our function to use named arguments?
#
# We can do so by exhausting all the positional arguments, and then adding some additional parameters in the function definition:

# %%
def func1(a, b, *args, d):
    print(a, b, args, d)
func1(10, 20, 'a', 'b', 100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\PythonCoreFundamentals\core.ipynb Cell 27' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/d%3A/PythonCoreFundamentals/core.ipynb#ch0000040?line=0'>1</a> def func1(a, b, *args, d):
#       <a href='vscode-notebook-cell:/d%3A/PythonCoreFundamentals/core.ipynb#ch0000040?line=1'>2</a>     print(a, b, args, d)
# ----> <a href='vscode-notebook-cell:/d%3A/PythonCoreFundamentals/core.ipynb#ch0000040?line=2'>3</a> func1(10, 20, 'a', 'b', 100)
#
# TypeError: func1() missing 1 required keyword-only argument: 'd'

# %%
func1(10, 20, 'a', 'b',d= 100)
# Out:
# 10 20 ('a', 'b') 100

# %%
def func1(*x, a, b):
    print(x)
    print(a)
    print(b)
func1(34343,a=2,b=4)
# Out:
# (34343,)
# 2
# 4

# %%
def func1(*, a, b):    #* ayexi aru positional arg auna paudina
    print(a)
    print(b)
func1(34343,a=2,b=4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\PythonCoreFundamentals\core.ipynb Cell 31' in <cell line: 4>()
#       <a href='vscode-notebook-cell:/d%3A/PythonCoreFundamentals/core.ipynb#ch0000045?line=1'>2</a>     print(a)
#       <a href='vscode-notebook-cell:/d%3A/PythonCoreFundamentals/core.ipynb#ch0000045?line=2'>3</a>     print(b)
# ----> <a href='vscode-notebook-cell:/d%3A/PythonCoreFundamentals/core.ipynb#ch0000045?line=3'>4</a> func1(34343,a=2,b=4)
#
# TypeError: func1() takes 0 positional arguments but 1 positional argument (and 2 keyword-only arguments) were given

# %% [markdown]
# Unlike positional parameters, keyword arguments do not have to be defined with non-defaulted and then defaulted arguments:

# %%
def func1(a, *, b='hello', c):
    print(a, b, c,sep="\t\t\t\t\t",end=".")
func1(5, c='bye')
# Out:
# 5					hello					bye.

# %% [markdown]
# #**kwargs

# %%
def func(**kwargs):
    print(kwargs)
func(x=1,y=4)
# Out:
# {'x': 1, 'y': 4}

# %% [markdown]
# #Nested Unpacking

# %%
a, b, (c, d) = [1, 2, ['X', 'Y']]
print(a)
print(b)
print(c)
print(d)
# Out:
# 1
# 2
# X
# Y

# %%
a, b, (c, d) = [1, 2, 'XY']
print(a)
print(b)
print(c)
print(d)
# Out:
# 1
# 2
# X
# Y

# %%
a, b, (c, d, *e) = [1, 2, 'python']
print(a)
print(b)
print(c)
print(d)
print(e)
# Out:
# 1
# 2
# p
# y
# ['t', 'h', 'o', 'n']

# %%
l = [1, 2, 3, 4, ['a', 'b', 'c', 'd']]
a, b, c, d, e = l[0], l[1:-1], l[-1][0], l[-1][1], list(l[-1][2:])
print(a)
print(b)  #with Slicing
print(c)
print(d)
print(e)
# Out:
# 1
# [2, 3, 4]
# a
# b
# ['c', 'd']

# %%
# Out:
# []
